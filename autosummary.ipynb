# %% [markdown]
# <a href="https://colab.research.google.com/github/convocat/hello-world/blob/master/autosummary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bs4
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1256 sha256=15e09abc80867f668f645237d698b019b05fe8cdbbdc0ca561a4406c422a1966
#   Stored in directory: /root/.cache/pip/wheels/25/42/45/b773edc52acb16cd2db4cf1a0b47117e2f69bb4eb300ed0e70
# Successfully built bs4
# ...

# %% [markdown]
# # Hier zit die hele brei aan HTML in. Dat kan straks 'iets anders' zijn, maar voor nu- werkt prima.
#
# ---

# %%
html = """<div class="ChapterTheory_container__1vht4" data-cy="theory-content">
    <div class="ChapterTheory_title__1qE6J">
        <div class="ChapterTheory_circle__2vrxI"><i class="Icon_icon__1L_lC ChapterTheory_iconTheory__2JPw6 icon-theory"
                data-cy=""></i></div>Theorie
    </div>
    <div class="ChapterTheory_theoryContainer__1eB0z">
        <h2 class="ChapterTheory_slideTitle__1QHC_" data-cy="slide-title">1. Economie en bedrijfseconomie</h2>
        <div class="Edify_container__yGkKg Edify_learningGoal__3QDhM" data-cy="">
            <div class=" pl-div  learning-goals MuiBox-root css-1xdhyk6" id="id-79265a74-8c63-40eb-b98a-277c404f48ef"
                type="div">
                <div class="pl-div-children">
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  title pl-paragraph title css-9rabg7"
                        id="id-d811e9f9-8c2d-4a4f-84dc-b8879af72e47" type="p"><span class="">Leerdoelen:</span></p>
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-bfec034c-82ba-4b6f-9ddb-7b92adf376b6" type="p"><span class="">Het verkrijgen van inzicht
                            in:</span></p>
                    <ul class="  css-8ac2me" id="id-79742129-0723-4e41-a67e-e7bbbcb86666">
                        <li id="id-3eec3bfd-3de4-4ca2-8799-449ee9d51295" class="css-i27ntf">
                            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                                id="id-c45572c5-57e1-44b4-a4e0-49f02b0519ef" type="p"><span class="">de deelgebieden van
                                    economie (</span><a variant="body1" id="id-c2cebfb1-ec7f-451c-ada5-cdad3c5f4057"
                                    class=" pl-reference" type="reference" color="default" data-type="edify-cross-link"
                                    href="#cross-link"><span class="">Economie en bedrijfseconomie</span></a><span
                                    class="">)</span></p>
                        </li>
                        <li id="id-af195b4c-fe27-4cd3-a397-25c204e57d20" class="css-i27ntf">
                            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                                id="id-f63ecee0-cb6f-4425-8926-b7cd975ad2b2" type="p"><span class="">het studieobject
                                    van bedrijfseconomie (</span><a variant="body1"
                                    id="id-f67eccef-2ccd-4344-9854-9e2b475634b7" class=" pl-reference" type="reference"
                                    color="default" data-type="edify-cross-link" href="#cross-link"><span
                                        class="">Economie en bedrijfseconomie</span></a><span class="">)</span></p>
                        </li>
                        <li id="id-af67efc6-259a-41bd-862e-2f7a99c4687b" class="css-i27ntf">
                            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                                id="id-a4709165-5573-4d1d-f901-3a917e53eb0a" type="p"><span class="">de kenmerken van
                                    ondernemingen (</span><a variant="body1"
                                    id="id-3693f629-f7d6-47af-96c4-790ff9e0a8d8" class=" pl-reference" type="reference"
                                    color="default" data-type="edify-cross-link" href="#cross-link"><span
                                        class="">Kenmerken van ondernemingen</span></a><span class="">)</span></p>
                        </li>
                        <li id="id-eab25fda-228f-4644-ff8c-a48e73eabce3" class="css-i27ntf">
                            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                                id="id-e809cfda-95b4-4839-8b2f-c4eeab6c235c" type="p"><span class="">de betekenis van
                                    efficiëntie en effectiviteit voor het streven naar winst van een onderneming
                                    (</span><a variant="body1" id="id-57573d9d-5084-4d1d-a67b-b2e42bedd820"
                                    class=" pl-reference" type="reference" color="default" data-type="edify-cross-link"
                                    href="#cross-link"><span class="">Kenmerken van ondernemingen</span></a><span
                                    class="">)</span></p>
                        </li>
                        <li id="id-f0d754d9-8640-42c6-d13f-488b039becb2" class="css-i27ntf">
                            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                                id="id-6999514e-56af-47c1-8658-b67d45c52b8c" type="p"><span class="">de kenmerken van
                                    non-profitorganisaties (</span><a variant="body1"
                                    id="id-4fbdde25-ad72-4c18-f412-08534bb755fb" class=" pl-reference" type="reference"
                                    color="default" data-type="edify-cross-link" href="#cross-link"><span
                                        class="">Kenmerken van non-profitorganisaties</span></a><span class="">)</span>
                            </p>
                        </li>
                        <li id="id-ece7528f-b00b-44c5-c33e-443e7972f818" class="css-i27ntf">
                            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                                id="id-0f375d16-cefd-408a-f285-34d1df9c52e8" type="p"><span class="">de indeling van
                                    bedrijven naar de vier hoofdsectoren (</span><a variant="body1"
                                    id="id-3201d181-5225-47f0-df73-d626d52037dd" class=" pl-reference" type="reference"
                                    color="default" data-type="edify-cross-link" href="#cross-link"><span
                                        class="">Ondernemingsactiviteiten</span></a><span class="">)</span></p>
                        </li>
                        <li id="id-b422691c-74c5-4924-b755-5ed6d0af91e1" class="css-i27ntf">
                            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                                id="id-8fb37479-f208-4d39-9387-e5a228a0f6a6" type="p"><span class="">de kenmerken van
                                    bedrijven in elk van de vier hoofdsectoren (</span><a variant="body1"
                                    id="id-70ec3cf1-4035-45fd-b9b9-03dd72e61561" class=" pl-reference" type="reference"
                                    color="default" data-type="edify-cross-link" href="#cross-link"><span
                                        class="">Ondernemingsactiviteiten</span></a><span class="">)</span></p>
                        </li>
                        <li id="id-214d2fd5-3aed-4107-adb4-cb9352647b9c" class="css-i27ntf">
                            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                                id="id-6ba56b25-8a30-4d31-92c7-d44590c54fd9" type="p"><span class="">de verschillende
                                    vormen van samenwerking in en tussen bedrijfskolommen (</span><a variant="body1"
                                    id="id-f104efc4-d69c-408f-a6a4-4aa78acbcffc" class=" pl-reference" type="reference"
                                    color="default" data-type="edify-cross-link" href="#cross-link"><span
                                        class="">Bedrijfskolom en bedrijfstak</span></a><span class="">)</span></p>
                        </li>
                        <li id="id-8dbd15cd-7a93-48ff-e51a-011332e333fb" class="css-i27ntf">
                            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                                id="id-36713f54-b9bc-4812-d0d6-3bac8d867cbe" type="p"><span class="">de kenmerken van
                                    fusie/overname, joint venture, franchising en kartel (</span><a variant="body1"
                                    id="id-5025ecd3-1d46-4d54-dbc4-a9864fe76bae" class=" pl-reference" type="reference"
                                    color="default" data-type="edify-cross-link" href="#cross-link"><span
                                        class="">Samenwerkingsvormen tussen ondernemingen</span></a><span
                                    class="">)</span></p>
                        </li>
                    </ul>
                </div>
            </div>
        </div>
        <div class="Edify_container__yGkKg" data-cy="">
            <section id="id-e108fb7d-6912-439c-969a-29276ef78b5c" class=" pl-section " type="section">
                <h4 class="MuiTypography-root MuiTypography-playerTitle MuiTypography-gutterBottom pl-section-title pl-title pl-title css-1ny8nnn"
                    id="id-090f65a5-129b-4062-c152-e81fb36fc42a" type="title"><span class="">Vereiste voorkennis:</span>
                </h4>
                <div class="pl-section-children">
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-0617d68d-24e0-4c69-8036-2f9b0dbd86cf" type="p"><span class="">Geen.</span></p>
                </div>
            </section>
            <section id="id-1f05138c-6e8f-4b5f-b101-600830aea130" class=" pl-section " type="section">
                <h4 class="MuiTypography-root MuiTypography-playerTitle MuiTypography-gutterBottom pl-section-title pl-title pl-title css-1ny8nnn"
                    id="id-296e33cc-0278-4b12-ed8e-43d29351e9a4" type="title"><span class="">Relatie met volgende
                        hoofdstukken:</span></h4>
                <div class="pl-section-children">
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-a856bc22-a5ac-417c-d7ab-f68d6eff4777" type="p"><i class="">Hoofdstuk </i><a
                            variant="body1" id="id-56b8138e-0c8c-4556-de8e-ba87b1b67c38" class=" pl-reference"
                            type="reference" color="default" data-type="edify-cross-link" href="#cross-link"><i
                                class="">Ondernemingen</i></a><span class=""> gaat dieper in op de verschillende vormen
                            waarin ondernemingen en bedrijven kunnen voorkomen. Met name het verschil tussen
                            ondernemingen zonder en met rechtspersoonlijkheid is hierin belangrijk. Bijzondere aandacht
                            besteden we aan </span><i class="">fiscale aspecten</i><span class=""> van
                            ondernemen.</span></p>
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-6d531952-a1be-410d-c7d2-e35095c0af2f" type="p"><i class="">Hoofdstuk </i><a
                            variant="body1" id="id-2e881e27-5fd1-4133-91ee-8c3322723545" class=" pl-reference"
                            type="reference" color="default" data-type="edify-cross-link" href="#cross-link"><i
                                class="">Bedrijfseconomische vakgebieden en functies</i></a><span class=""> deelt de
                            bedrijfseconomie in naar drie hoofdgebieden: </span><i class="">financiering</i><span
                            class="">, </span><i class="">management accounting</i><span class=""> en </span><i
                            class="">financial accounting</i><span class="">. Ook geeft het hoofdstuk de samenhang met
                            andere vakgebieden en bespreekt het de meest relevante functies voor iemand met
                            bedrijfseconomische kennis.</span></p>
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-3b81019b-cf41-461d-a271-fe2427c61c28" type="p"><i class="">Hoofdstuk </i><a
                            variant="body1" id="id-266a8406-7db0-4d83-85ec-eb46bb9986f7" class=" pl-reference"
                            type="reference" color="default" data-type="edify-cross-link" href="#cross-link"><i
                                class="">Financiële overzichten</i></a><span class=""> bespreekt de belangrijkste
                            financiële overzichten voor een onderneming. De </span><i class="">balans</i><span class="">
                            geeft een overzicht van enerzijds de waarde van de productiemiddelen waarin de onderneming
                            geïnvesteerd heeft en anderzijds van de manier waarop deze productiemiddelen gefinancierd
                            zijn. Ook gaat het hoofdstuk in op het verschil tussen </span><i class="">winst</i><span
                            class=""> en mutatie van de liquide middelen. Winst is het verschil tussen opbrengsten en
                            kosten, en de mutatie van de liquide middelen is het verschil tussen ontvangsten en
                            uitgaven.</span></p>
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-4bdb95fa-e9e1-49ce-c695-2c330bc4fce3" type="p"><i class="">Hoofdstuk </i><a
                            variant="body1" id="id-91f74917-9821-4411-c8ff-cdeb563e60c7" class=" pl-reference"
                            type="reference" color="default" data-type="edify-cross-link" href="#cross-link"><i
                                class="">Ondernemingsplan</i></a><span class=""> gaat over het opstellen van een
                            ondernemingsplan, waarin de financiële overzichten een cruciale rol spelen.</span></p>
                </div>
            </section>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="15120df0-035d-4895-91be-41c11ba15035" type="p"><b class="">Economie</b></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-fe310b2e-162c-4ab7-bd3a-33b7e0227489" type="p"><span class="">Mensen hebben veel nodig: een huis,
                    voedsel, een mooie auto of fiets, ontspanning in de vorm van een weekendje weg, enzovoort. Al deze
                    goederen en diensten moeten worden ‘geproduceerd’. Om over een auto te kunnen beschikken moet er een
                    fabrikant van auto’s zijn; voor het weekendje weg moet er een hotel te zijn. Voordat er op grote
                    schaal ruilhandel ontstond, was iedere consument tevens producent: hij bakte zijn eigen brood en
                    bouwde zelf zijn huis. In de ontwikkelde </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-d8dba1d6-f832-44c3-cce4-9a1d603851f7" type="reference"
                    data-pixel="Link"><span><span class="">economie</span></span></a><span class=""> is dit niet meer
                    het geval.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-0d42dc11-9d98-4048-f3bd-a26cacb84db8" type="p"><span id="marginWord-Productiehuishoudingen"
                    class="css-0"></span><span class="">Productiehuishoudingen, ook wel bedrijven genoemd, vervaardigen
                    goederen en diensten en verkopen deze aan de consument voor een bepaalde vaak hoge prijs. De
                    consument beschikt over de benodigde koopkracht door het inkomen dat hij verdient in de
                    productiehuishoudingen.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-63464b9c-dc61-4477-abb7-efcf55e2f991" type="p"><span class="">De </span><span
                    id="marginWord-Economische wetenschap" class="css-0"></span><i class="">economische
                    wetenschap</i><span class=""> (</span><i class="">economics</i><span class="">) houdt zich bezig met
                    de vraagstukken die samenhangen met het streven naar welvaart van de mens: hoe kan iemand optimaal
                    voorzien in goederen en diensten, dat wil zeggen met zo gering mogelijke opoffering van
                    middelen.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-5e11309f-f5f8-4517-ca89-a3089d809e33" type="p"><span class="">De </span><span
                    id="marginWord-Algemene economie" class="css-0"></span><i class="">algemene economie</i><span
                    class=""> (</span><i class="">general economics</i><span class="">) bestudeert de relaties tussen
                    consumenten en producenten en tussen de producenten onderling. Daarbij kan een onderscheid worden
                    gemaakt tussen micro- en macro-economie. Tot het werkterrein van de </span><span
                    id="marginWord-Micro-economie" class="css-0"></span><i class="">micro-economie</i><span class="">
                    (</span><i class="">microeconomics</i><span class="">) behoort onder andere de theorie van de
                    marktvormen: hoe komt de prijsvorming op een bepaalde markt, bijvoorbeeld de markt voor
                    vakantiereizen, tot stand? Bepalend daarvoor is onder andere het aantal aanbieders en het aantal
                    vragers op die markt. De </span><span id="marginWord-Macro-economie" class="css-0"></span><i
                    class="">macro-economie</i><span class=""> (</span><i class="">macroeconomics</i><span class="">)
                    houdt zich bezig met economische problemen van de maatschappij als geheel, zoals inflatie en
                    werkloosheid.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-c62d6ca6-f963-4e87-c287-96c94b28b1bb" type="p"></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="e8247288-1cb0-48a7-93b1-878fff71aeeb" type="p"><b class="">Bedrijfseconomie</b></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-c90c6820-14f9-4847-8c61-44c74e57e8b3" type="p"><span class="">De </span><span
                    id="marginWord-Bedrijfseconomie" class="css-0"></span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-46be434c-7a99-42c7-db21-2ec3fc13bbc9" type="reference"
                    data-pixel="Link"><span><i class="">bedrijfseconomie</i></span></a><span class=""> (</span><i
                    class="">business economics</i><span class="">) richt zich op het economisch handelen binnen de
                    productieorganisaties, gewoonlijk bedrijven genoemd. ‘Productie’ dient hier ruim opgevat te worden:
                    het gaat niet alleen om de </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-edc16f68-cfda-4b2a-9613-29c617cc9f85" type="reference"
                    data-pixel="Link"><span><span class="">productie</span></span></a><span class=""> van fysieke
                    goederen, maar ook om de </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-25984c9f-45a7-4f97-facd-52fd4d755cd0" type="reference"
                    data-pixel="Link"><span><span class="">handel</span></span></a><span class=""> en het verlenen van
                    diensten. Zo is bijvoorbeeld niet alleen een autofabriek, maar ook een autodealer en een
                    autowerkplaats een productieorganisatie in economische zin.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-85114783-37ee-4ccb-a219-d83c5bb6fe45" type="p"><span class="">In het economische stelsel zoals
                    wij dat kennen, is de ondernemingsgewijze productie belangrijk. </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-1f23da06-fbd4-4906-f0c8-2c5f1fa5fd0e" type="reference"
                    data-pixel="Link"><span><span class="">Ondernemingen</span></span></a><span class=""> (</span><i
                    class="">companies</i><span class="">) zijn productieorganisaties die erop gericht zijn om ‘op de
                    markt’ inkomen te verdienen voor hun eigenaren. Het zijn dus productieorganisaties die naar
                </span><span id="marginWord-Winst" class="css-0"></span><span class=""> </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-169cb38c-e67c-429c-a021-fc41d38b0b10" type="reference"
                    data-pixel="Link"><span><i class="">winst</i></span></a><span class=""> (</span><i class="">profit,
                    income</i><span class="">) streven.</span></p>
        </div>
    </div>
    <div class="ChapterTheory_theoryContainer__1eB0z">
        <h2 class="ChapterTheory_slideTitle__1QHC_" data-cy="slide-title">2. Kenmerken van ondernemingen</h2>
        <div class="Edify_container__yGkKg" data-cy="">
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="3b4b219d-a083-4a65-99a8-f133bdd91c4d" type="p"><b class="">Een onderneming is een
                    productieorganisatie</b></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-d59e3e12-5963-4af2-97ce-71708aeec5e5" type="p"><span class="">In een productieorganisatie worden
                    productiemiddelen bij elkaar gebracht en vervolgens in een productieproces omgezet in producten. Een
                    productieorganisatie opereert tussen twee markten: op de inkoopmarkt worden de productiemiddelen
                    verkregen, op de verkoopmarkt worden de geproduceerde goederen of diensten verkocht.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-457ccaf6-1de2-4dfa-8aac-3cfdc4428519" type="p"><span class="">De productiemiddelen kunnen bestaan
                    uit grondstoffen enerzijds en uit machines, gebouwen en dergelijke anderzijds. Deze laatste worden
                    duurzame productiemiddelen genoemd, omdat zij – in tegenstelling tot de grondstoffen – gedurende
                    langere tijd hun diensten aan de </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-9f5292b6-edb0-418b-8650-eacfd723d3eb" type="reference"
                    data-pixel="Link"><span><span class="">ondernemingen</span></span></a><span class=""> bewijzen.
                    Uiteraard vormt de arbeidskracht van de medewerkers ook een productiemiddel.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-9092e674-0db7-4759-9eb8-dd0d112ea170" type="p"><span class="">In figuur </span><a variant="body1"
                    id="id-63bd9367-b0ba-4ebc-9617-e2fcd79b7aee" class=" pl-reference" type="reference" color="default"
                    href="#id-23cfb891-d4fd-4a0a-83b9-65669875b011"><span class="">Productieproces</span></a><span
                    class=""> is het productieproces schematisch weergegeven.</span></p>
            <figure id="id-23cfb891-d4fd-4a0a-83b9-65669875b011" class="pl-figure-img  css-1hxcr1q">
                <div class="pl-image-box MuiBox-root css-0"><img class="pl-image css-tw5ok2"
                        src="https://damapi-assets.edify.noordhoff.nl/image-output/edify-casper.prd-noordhoff.a91f87c0-5a69-46c9-865d-2914a95bd55a/fontopreview.jpeg?lastmodified=1604578532906"
                        alt="" loading="lazy"></div>
                <div class="pl-figure-description MuiBox-root css-dz0mqj">
                    <h4 class="MuiTypography-root MuiTypography-playerTitle MuiTypography-gutterBottom  pl-title css-1ny8nnn"
                        id="id-347ba7ff-7378-45ac-aa08-77070a82c563" type="title"><span class="">Productieproces</span>
                    </h4>
                </div>
            </figure>
            <div class=" pl-example  example MuiBox-root css-1xdhyk6" id="id-b3855cba-0bf5-4069-c43f-ad3c304f5de7"
                type="example">
                <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom pl-example-title pl-title pl-paragraph title css-9rabg7"
                    id="id-599a48e9-e21c-47a2-c854-8a1eff4e9290" type="p"><span class="">Coca Cola</span></p>
                <div class="pl-example-children">
                    <figure id="id-0946c43e-b61c-4a42-cf80-19638827a3fc" class="pl-figure-img  css-1hxcr1q">
                        <div class="pl-image-box MuiBox-root css-0"><img class="pl-image css-tw5ok2"
                                src="https://damapi-assets.edify.noordhoff.nl/image-output/edify-casper.prd-noordhoff.b9fbce6c-bdc5-45a3-af85-25d0b1f4b087/fontopreview.jpeg?lastmodified=1604668926782"
                                alt="" loading="lazy"></div>
                    </figure>
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-39a0b8fd-bd49-45ea-b39f-731f6372381b" type="p"><span class="">Voor de </span><a
                            class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                            href="javascript:" id="id-ce354443-9bc3-412d-cea4-5a74c7917786" type="reference"
                            data-pixel="Link"><span><span class="">productie</span></span></a><span class=""> van cola
                            maakt Coca Cola gebruik van grondstoffen. Coca Cola bevat 89% koolzuurhoudend water (water,
                            koolstofdioxide, natrium) en daarnaast suiker, karamel, fosforzuur, cafeïne en een mix van
                            cocablad, vruchtenextracten, vanille en specerijen. De exacte mix plantenextracten is tot op
                            de dag van vandaag de bekendste geheime formule ter wereld.</span></p>
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-e890a603-742a-4874-d0db-3215f7cf5085" type="p"><span class="">Behalve de grondstoffen
                            dient Coca Cola uiteraard ook te beschikken over duurzame productiemiddelen: bottelarijen,
                            distributiecentra, vrachtauto’s voor het transport, computers en nog vele andere
                            productiemiddelen. Uiteraard vormen de medewerkers een onmisbare schakel in het
                            geheel.</span></p>
                </div>
            </div>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-bc9e6d62-f4d5-4bdb-9b51-316fd041414c" type="p"><span class="">De grondstoffen en duurzame
                    productiemiddelen worden aangeduid als het </span><span id="marginWord-Kapitaal"
                    class="css-0"></span><i class="">kapitaal</i><span class=""> (</span><i class="">capital</i><span
                    class="">) van de </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-d2704530-ad11-4658-fd8b-636e710bae24" type="reference"
                    data-pixel="Link"><span><span class="">organisatie</span></span></a><span class="">. De
                    productieorganisatie is dus een samenwerkingsverband van de productiefactoren arbeid en </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-5321d99c-bc14-40db-bf50-537a6bedd7c8" type="reference"
                    data-pixel="Link"><span><span class="">kapitaal</span></span></a><span class="">.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-841fe72d-6236-4550-ada1-707e0ae6b527" type="p"><span class="">Het samenwerkingsverband kan een
                    formeel karakter hebben, waarbij de rechten en plichten van de bij de organisatie betrokken
                    participanten schriftelijk zijn vastgelegd: in de statuten en in taakomschrijvingen worden dan de
                    bevoegdheden van aandeelhouders, directie en medewerkers opgeschreven.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-b6367602-4ec3-4b59-81a0-88a06f7a4b07" type="p"><span class="">Er is echter ook sprake van een
                    productieorganisatie als twee studenten samen een koeriersdienst oprichten, waarbij de enige
                    afspraak is dat er afwisselend een bij de telefoon zit en de ander op de scooter onderweg is.</span>
            </p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="10a18008-f464-4e84-8401-3e0fbedb9e3f" type="p"><b class="">Een onderneming streeft naar winst</b>
            </p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-7e32ead6-a501-4e31-c2db-e3aeb237c3bb" type="p"><span class="">Een onderneming neemt deel aan het
                    economische proces, opdat de eigenaren er ‘beter’ van worden. Zij streeft naar ‘waardecreatie’: de
                    opbrengst van de verkoop van de geproduceerde goederen of diensten zal meer moeten zijn dan de prijs
                    die zij op de inkoopmarkt betaalt voor de productiefactoren (arbeid, grondstoffen, duurzame
                    productiemiddelen). Het overschot dat behaald wordt, de </span><i class="">winst</i><span class="">
                    (= opbrengsten – kosten), komt vervolgens ten goede aan de eigenaren van de onderneming.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-0eab0a1b-4fbb-4232-c6f1-05e204bf5e40" type="p"><span class="">Het streven naar </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-770122a1-dd40-471f-bdba-e92e7fc2f502" type="reference"
                    data-pixel="Link"><span><span class="">winst</span></span></a><span class=""> onderscheidt
                    ondernemingen van bedrijven in het algemeen. Elk </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-11e16b71-1850-4514-bacb-6b079b7a5c49" type="reference"
                    data-pixel="Link"><span><span class="">bedrijf</span></span></a><span class=""> brengt goederen
                    en/of diensten voort. In de volgende paragraaf gaan we in op bedrijven die het maken van winst niet
                    als doel hebben.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-28fc3a69-45c8-450b-92a0-a1f5f7962215" type="p"><span class="">De grootte van de winst is
                    afhankelijk van enerzijds de </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-19f6fb6e-1764-4fe6-c005-ce0af4b8ec5b" type="reference"
                    data-pixel="Link"><span><span class="">efficiëntie</span></span></a><span class=""> en anderzijds de
                </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-aed7bd68-ea74-4003-8cf8-1bc7826d70d9" type="reference"
                    data-pixel="Link"><span><span class="">effectiviteit</span></span></a><span class=""> van het
                    productieproces. Onder de </span><span id="marginWord-Efficiëntie" class="css-0"></span><i
                    class="">efficiëntie</i><span class=""> (</span><i class="">efficiency</i><span class="">) wordt de
                    doelmatigheid van het productieproces verstaan, ofwel het bereiken van een doel met gebruik van zo
                    weinig mogelijk middelen. Onder de </span><span id="marginWord-Effectiviteit"
                    class="css-0"></span><i class="">effectiviteit</i><span class=""> (</span><i
                    class="">effectiveness</i><span class="">) wordt de doelgerichtheid van het productieproces
                    verstaan, ofwel de mate waarin het eindproduct geschikt is om te voldoen aan de eisen van de
                    afnemers.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-291ffdca-1bc3-47cd-a78f-63bf66d11f41" type="p"><span class="">Een productieproces is efficiënt
                    als een gegeven hoeveelheid met zo gering mogelijke </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-4801d4cf-0c4e-4fbc-8fe2-f28735e64e83" type="reference"
                    data-pixel="Link"><span><span class="">kosten</span></span></a><span class=""> wordt geproduceerd.
                    Het is effectief als dat een eindproduct oplevert dat in trek is bij de klanten, waar de klanten
                    graag voor willen betalen.</span></p>
            <div class=" pl-example  example MuiBox-root css-1xdhyk6" id="id-8d9045d2-30ff-49d9-d43d-070a5817f00c"
                type="example">
                <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom pl-example-title pl-title pl-paragraph title css-9rabg7"
                    id="id-4bd542be-094c-4e09-fff0-ce727e8cece1" type="p"><span class="">Coca Cola (Vervolg)</span></p>
                <div class="pl-example-children">
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-891b7658-c8ea-4220-d0bc-43a058c718dc" type="p"><span class="">Coca Cola zal ernaar
                            streven om de productie van een cola te realiseren met een zo zuinig mogelijke inzet van
                            arbeid en kapitaalgoederen. Bij gegeven kwaliteitsnormen zal gepoogd worden de kostprijs zo
                            laag mogelijk te laten zijn. De kostprijs is dus een maatstaf voor de efficiëntie.</span>
                    </p>
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-6c8e0217-ef50-4927-f51c-d0895c7893ec" type="p"><span class="">Het eindproduct zal zodanig
                            moeten zijn dat het een marktaandeel verwerft en behoudt op de markt voor frisdranken. De
                            smaak van de cola, de prijs-kwaliteitverhouding en de positionering door reclame moeten
                            daaraan bijdragen. De mate waarin Coca Cola erin slaagt verkoopopbrengsten te behalen, geeft
                            de effectiviteit aan.</span></p>
                </div>
            </div>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-928db317-b741-4b9e-9674-4035d3626c16" type="p"><span class="">In figuur </span><a variant="body1"
                    id="id-093f2142-089f-4a3a-fc05-c00e376fb469" class=" pl-reference" type="reference" color="default"
                    href="#3b4b219d-a083-4a65-99a8-f133bdd91c4d_id-23cfb891-d4fd-4a0a-83b9-65669875b011#id-23cfb891-d4fd-4a0a-83b9-65669875b011"><span
                        class="">Efficiëntie en effectiviteit in het voortbrengingsproces</span></a><span class="">
                    wordt de rol van efficiëntie en effectiviteit in het productieproces weergegeven.</span></p>
            <figure id="id-d6aacb0f-55ba-41ec-9955-8b11ce1550f1" class="pl-figure-img  css-1hxcr1q">
                <div class="pl-image-box MuiBox-root css-0"><img class="pl-image css-tw5ok2"
                        src="https://damapi-assets.edify.noordhoff.nl/image-output/edify-casper.prd-noordhoff.8b441fe6-30b0-45bf-9b07-35c08702f338/fontopreview.jpeg?lastmodified=1604578559404"
                        alt="" loading="lazy"></div>
                <div class="pl-figure-description MuiBox-root css-dz0mqj">
                    <h4 class="MuiTypography-root MuiTypography-playerTitle MuiTypography-gutterBottom  pl-title css-1ny8nnn"
                        id="id-da90372d-8533-4782-c185-d1bb75f7baaa" type="title"><span class="">Efficiëntie en
                            effectiviteit in het voortbrengingsproces</span></h4>
                </div>
            </figure>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-6995bf3a-2dac-46cf-f7ab-bb37ba5337b3" type="p"><span class="">Kenmerkend voor een onderneming is
                    dat het</span><span id="marginWord-Winstcijfer" class="css-0"></span><span class="">winstcijfer een
                    maatstaf is voor zowel de efficiëntie als de effectiviteit: het is immers het saldo van de
                </span><span id="marginWord-Omzet" class="css-0"></span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-cac461d2-ced8-412f-ef78-6a5037dab40a" type="reference"
                    data-pixel="Link"><span><span class="">omzet</span></span></a><span class=""> (</span><i
                    class="">sales revenue, turnover</i><span class="">) (maatstaf voor effectiviteit) en Kostenkosten
                    (costs) (maatstaf voor efficiëntie).</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-a13059ee-a3ff-4090-d67b-1f8db168da2e" type="p"><span class="">Het behalen van winst staat bij een
                    onderneming voorop; op welke manier die winst behaald wordt is een secundaire kwestie. Als een
                    rederij constateert dat de scheepvaartactiviteiten geen winstperspectief meer bieden, zal zij er in
                    principe geen moeite mee hebben om over te schakelen op een andere activiteit. Uiteraard zullen
                    sommige medewerkers er verdriet van hebben dat er een rijk stuk scheepvaarthistorie verloren gaat,
                    maar de financiële overwegingen gaan voor.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-bec85401-c583-4e71-8d2a-0696aa8fe5dd" type="p"><span class="">Een mooi voorbeeld daarvan is
                    Koninklijke Philips nv. In 1891 begonnen als gloeilampenfabriek waarna er allerlei andere producten
                    bij kwamen: huishoudelijke apparaten zoals scheerapparaten, elektrische tandenborstels,
                    koffiezetapparaten en consumentenelektronica zoals tv’s en stereo’s.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-67a34b12-0216-47cf-a36b-442b5bc02224" type="p"><span class="">Inmiddels legt Philips zich
                    volledig toe op de ontwikkeling en productie van technologieën op het gebied van gezondheidszorg. De
                    lampenfabriek is verzelfstandigd. De overige producten die nog onder de merknaam Philips worden
                    aangeboden worden in feite door andere ondernemingen geproduceerd.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-9282f154-9964-4512-8672-b7cfff3f3cf4" type="p"><span class="">De winst vormt dus het doel, de
                    activiteiten het middel. We maken hierbij echter enige kanttekeningen:</span></p>
            <ul class="  css-8ac2me" id="id-7b2dcae4-2f3f-4eb7-91ae-72a72e7fe276">
                <li id="id-ab913dac-808f-41d5-da66-1b23e90fc3d7" class="css-i27ntf">
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-71af83a7-09ce-43a0-ad87-2f39cf8b774a" type="p"><span class="">Streven naar winst ‘tot
                            elke prijs’ is meestal niet aan de orde. De </span><span id="marginWord-Continuïteit"
                            class="css-0"></span><i class="">continuïteit</i><span class=""> (</span><i
                            class="">continuity</i><span class="">) van de onderneming vormt eveneens een belangrijk
                            uitgangspunt. Om het voortbestaan van de onderneming te verzekeren, is het behalen van winst
                            echter noodzakelijk; alleen dan beschikt de onderneming over de financiële middelen om
                            zelfstandig te kunnen overleven.</span></p>
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-09370148-f448-4492-9eb1-7aa29e679f92" type="p"><span class="">Voor de </span><a
                            class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                            href="javascript:" id="id-a54f56b5-3954-45e6-ec54-5ef375f602d0" type="reference"
                            data-pixel="Link"><span><span class="">continuïteit</span></span></a><span class=""> van de
                            onderneming is het wel noodzakelijk dat het winststreven ook vanuit langetermijnperspectief
                            bekeken wordt: een snelle winst pakken door slechte producten als topkwaliteit aan te
                            bieden, werkt op de lange termijn averechts.</span></p>
                </li>
                <li id="id-e143d320-6e2b-4f18-ef3c-0336dd31dab8" class="css-i27ntf">
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-a4df056b-448c-46f5-de61-cd07b07adab3" type="p"><span class="">Het lijkt er soms op dat
                            niet het streven naar een zo groot mogelijke winst, maar het streven naar een zo groot
                            mogelijke omzet tot belangrijkste ondernemingsdoel is verheven. Voor ondernemingsbestuurders
                            lijkt vaak te gelden: hoe groter hoe beter. Bedrijven worden bijvoorbeeld overgenomen,
                            zonder dat dat besluit gebaseerd is op gefundeerde verwachtingen van een extra bijdrage aan
                            de winst.</span></p>
                </li>
                <li id="id-5ba71d42-5520-439f-f1d6-20802dbdc79b" class="css-i27ntf">
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-62475d69-76fe-488c-9d36-b3b15b98aa86" type="p"><span class="">Als ondernemingen zelf hun
                            doel beschrijven, bijvoorbeeld op hun website, komt het winststreven meestal niet prominent
                            naar voren, wel zaken als de zorg voor het milieu, de arbeidsvreugde bij de werknemers,
                            enzovoort. We geven hier enkele voorbeelden van grote ondernemingen:</span></p>
                </li>
            </ul>
            <div class=" pl-div  internet MuiBox-root css-1xdhyk6" id="id-0c96aebc-26f0-4b32-dcb1-f9bf29d287de"
                type="div">
                <div class="pl-div-children">
                    <h4 class="MuiTypography-root MuiTypography-playerTitle MuiTypography-gutterBottom  level-1 pl-title level-1 css-1ny8nnn"
                        id="id-38433c4c-e6eb-46d2-b941-dfaa68a8c255" type="title"><span class="">Philips:</span></h4>
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-702151df-51c3-416b-9a4b-a7f0a886ce8c" type="p"><span class="">At Philips, we strive to
                            make the world healthier and more sustainable through innovation. Our goal is to improve the
                            lives of 3 billion people a year by 2030. We will be the best place to work for people who
                            share our passion. Together we will deliver superior value for our customers and
                            shareholders.</span></p>
                    <h5 class="MuiTypography-root MuiTypography-playerSubHeader MuiTypography-gutterBottom  level-2 pl-paragraph level-2 css-8zhl27"
                        id="id-65c8c3f6-780b-485b-fa80-63c229275cf2" type="p"><span class="">Coca-Cola:</span></h5>
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-8177eb46-496c-4fd3-cbe6-ac8477b8d502" type="p"><span class="">To refresh the
                            world...</span></p>
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-27e8fbb4-07eb-477e-b59d-143a786598d6" type="p"><span class="">To inspire moments of
                            optimism and happiness...</span></p>
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-236f2706-9944-44f3-d715-84fe117796cc" type="p"><span class="">To create value and make a
                            difference.</span></p>
                    <h5 class="MuiTypography-root MuiTypography-playerSubHeader MuiTypography-gutterBottom  level-2 pl-paragraph level-2 css-8zhl27"
                        id="id-9274053b-8efe-4d1d-b16c-350c58ebc23c" type="p"><span class="">Shell:</span></h5>
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-1ecf740c-8266-4a02-f730-7a4db046c551" type="p"><span class="">Shell's purpose is to power
                            progress together with more and cleaner energy solutions. We believe that rising standards
                            of living for a growing global population are likely to continue to drive demand for energy,
                            including oil and gas, for years to come. At the same time, technology changes and the need
                            to tackle climate change means there is a transition underway to a lower-carbon, multisource
                            energy system.</span></p>
                </div>
            </div>
        </div>
    </div>
    <div class="ChapterTheory_theoryContainer__1eB0z">
        <h2 class="ChapterTheory_slideTitle__1QHC_" data-cy="slide-title">3. Kenmerken van non-profitorganisaties</h2>
        <div class="Edify_container__yGkKg" data-cy="">
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-e4e2de7b-c407-46d2-8c1a-273220819ad0" type="p"><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-40e313e6-6cf0-4d3a-fe93-21d082d7a459" type="reference"
                    data-pixel="Link"><span><span class="">Ondernemingen</span></span></a><span class=""> streven naar
                </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-e5348da5-d9af-4528-f603-212fb6a461a0" type="reference"
                    data-pixel="Link"><span><span class="">winst</span></span></a><span class=""> en behoren dus tot de
                    profitsector. In dit boek zal de aandacht vooral gericht worden op deze sector. Daarnaast zijn er
                    vele </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-e1730b24-b225-426a-8f71-44d9971944e4" type="reference"
                    data-pixel="Link"><span><span class="">non-profitorganisaties</span></span></a><span class="">.
                    Hierbij kan een onderscheid gemaakt worden tussen de </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-66a7f66b-c350-4174-ce2c-9fd7d0476de7" type="reference"
                    data-pixel="Link"><span><span class="">overheidssector</span></span></a><span class=""> en de
                    ‘particuliere’ non-profitinstellingen.</span></p>
            <ul class="  css-8ac2me" id="id-ff8c1824-79c3-42a0-a4bd-fd4c1e4820a3">
                <li id="id-9e674960-4602-4e2d-c09a-d3e171719583" class="css-i27ntf">
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-2db20917-37e7-41e5-b9fd-6b1a4d352b90" type="p"><span id="marginWord-Overheidssector"
                            class="css-0"></span><span class="">De </span><i class="">overheidssector</i><span class="">
                            (</span><i class="">public sector</i><span class="">) bestaat uit nationale,
                            staats-/provinciale en lokale overheden. De overheid levert vooral </span><i
                            class="">collectieve goederen en diensten</i><span class="">; dit zijn voorzieningen die tot
                            stand gebracht worden voor de bevolking als geheel, zoals wegen, bescherming tegen het water
                            en veiligheid. Deze voorzieningen kunnen niet door ondernemingen voortgebracht worden,
                            aangezien het </span><span id="marginWord-Marktmechanisme" class="css-0"></span><i
                            class="">marktmechanisme</i><span class=""> (</span><i class="">market mechanism</i><span
                            class="">) hier verstek laat gaan. Het </span><a
                            class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                            href="javascript:" id="id-c3664b4a-a194-45d7-8441-81608a963d5f" type="reference"
                            data-pixel="Link"><span><span class="">marktmechanisme</span></span></a><span class="">
                            bestaat uit het vrije spel van vraag naar en aanbod van goederen of diensten, waardoor
                            prijzen tot stand komen. Bij collectieve goederen kunnen individuele consumenten niet alleen
                            voor zichzelf bijvoorbeeld een stukje bescherming tegen hoog water kopen. Vandaar dat voor
                            de voortbrenging van collectieve goederen en diensten het </span><span
                            id="marginWord-Budgetmechanisme" class="css-0"></span><a
                            class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                            href="javascript:" id="id-ebe484ce-6768-4e17-cea8-41c553a8b015" type="reference"
                            data-pixel="Link"><span><i class="">budgetmechanisme</i></span></a><span class="">
                            (</span><i class="">budget mechanism</i><span class="">) wordt ingeschakeld: de overheid
                            heft gedwongen bijdragen (belastingen) en stelt een budget beschikbaar waarmee de </span><a
                            class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                            href="javascript:" id="id-1e038fc8-fa85-4584-bb83-48c33ca9affd" type="reference"
                            data-pixel="Link"><span><span class="">productie</span></span></a><span class=""> van de
                            collectieve goederen kan worden gefinancierd.</span></p>
                </li>
                <li id="id-424d44aa-b682-4f40-b5d0-b20907c78b34" class="css-i27ntf">
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-3030bd37-c37b-4249-aeec-c3bbdd383737" type="p"><span class="">Er zijn ook algemene
                            voorzieningen die in het verleden door de overheid ter hand zijn genomen om daarmee invloed
                            te kunnen uitoefenen op de beschikbaarheid van die voorzieningen voor grote groepen, maar
                            die in principe ook door ondernemingen kunnen worden verstrekt. De laatste jaren zien we bij
                            de overheid een trend tot </span><span id="marginWord-Privatisering" class="css-0"></span><i
                            class="">privatisering</i><span class=""> van dit soort activiteiten: activiteiten die zich
                            daartoe lenen, worden losgemaakt van de overheidsorganisatie en moeten ‘op de markt’ hun
                            bestaan bewijzen. Voorbeelden zijn openbaar vervoer, telefonie, postbezorging en opwekking
                            en levering van energie.</span></p>
                </li>
                <li id="id-56d40512-3f1e-41c9-db55-c9a10fb435e1" class="css-i27ntf">
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-fcc9950c-99d8-4d21-f2ad-f41e807d526c" type="p"><i class="">Particuliere
                            non-profitinstellingen</i><span class=""> vormen een rijke verscheidenheid aan </span><a
                            class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                            href="javascript:" id="id-ad2fec7a-4a62-4761-9c6d-6ce900ee7b48" type="reference"
                            data-pixel="Link"><span><span class="">organisaties</span></span></a><span class="">:
                            amateursportverenigingen vallen eronder, maar ook allerlei 'goededoelenorganisaties’, zoals
                            het Rode Kruis. Deze laatste groep wordt wel aangeduid als de fondsenwervende instellingen,
                            omdat zij proberen geld in te zamelen om een bepaald maatschappelijk nastrevenswaardig doel
                            te bereiken.</span></p>
                </li>
            </ul>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="e55ba69f-0e12-4491-bbba-289b85d2c97a" type="p"><b class="">Verschillen met ondernemingen</b></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-ccdbfb82-6488-4226-c37c-dcd3f2b15198" type="p"><span class="">Organisaties in de non-profitsector
                    verschillen in de volgende opzichten van ondernemingen:</span></p>
            <ul class="  css-8ac2me" id="id-4d81244d-6ec4-44b8-f3f0-354efd53e970">
                <li id="id-8c04a2d1-3b9a-4416-fb95-ab2f98bab0bb" class="css-i27ntf">
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-1b77a25b-3545-4ec4-b92c-7f04deb36851" type="p"><span class="">Non-profitorganisaties
                            hebben als doel om bepaalde (maatschappelijk van belang geachte) voorzieningen tot stand te
                            brengen. De activiteiten die zij verrichten zijn dus direct verbonden met dat doel. Artsen
                            zonder Grenzen verricht geneeskundige activiteiten in ontwikkelingslanden omdat dat haar
                            bestaansrecht is. Overschakeling op andere activiteiten uit financieel-economische
                            overwegingen is niet aan de orde. De donateurs zouden er zeer grote bezwaren tegen hebben
                            als de organisatie zich ineens met andere activiteiten zou gaan bezighouden. Aandeelhouders
                            van een profitorganisatie als Unilever daarentegen zullen er niet wakker van liggen als die
                            de fabricage van wasmiddelen inruilt voor een andere activiteit, als dat een hogere winst
                            belooft.</span></p>
                </li>
                <li id="id-ed8ed889-249e-48d9-cece-745d800a65f5" class="css-i27ntf">
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-6a2598cc-a4fb-4a3e-f5d5-ff22a6c01aa7" type="p"><span class="">Non-profitorganisaties
                            kunnen normaliter niet voortbestaan door zakelijke markttransacties uit te voeren, en zijn
                            dus – in tegenstelling tot ondernemingen – economisch niet zelfstandig. Ze zijn afhankelijk
                            van contributies, donaties, subsidies, schenkingen, erfenissen en dergelijke. In beperkte
                            mate kan een non-profitorganisatie ook ‘op de markt’ opereren, door bijvoorbeeld T-shirts
                            met opdruk te verkopen.</span></p>
                </li>
                <li id="id-6b7f7256-1ced-420e-db4a-9a1cf1b0294d" class="css-i27ntf">
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-7ba03483-d46b-4e68-df7b-19d707b38571" type="p"><span class="">De beoordeling van de
                        </span><a
                            class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                            href="javascript:" id="id-528b4bec-ed65-40b0-bbad-edcbfadcdfb1" type="reference"
                            data-pixel="Link"><span><span class="">effectiviteit</span></span></a><span class=""> is bij
                            non-profitinstellingen veel moeilijker dan bij ondernemingen. Bij die laatste geeft – zoals
                            we eerder hebben geconstateerd – het winstcijfer de mate aan waarin zowel efficiënt als
                            effectief is geproduceerd. Zo’n winstcijfer kan uiteraard niet gebruikt worden in de
                            non-profitsector.</span></p>
                </li>
                <li id="id-41732bad-8557-416c-b8bd-b49c96d5831f" class="css-i27ntf">
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-1af67b2c-2226-4be8-c350-c4b85e0a1f22" type="p"><span class="">Een stichting die zich
                            bezighoudt met slachtofferhulp is effectief als zij erin slaagt de problemen van haar
                            cliënten zo goed mogelijk op te lossen. Uiteraard kan dat niet in geld uitgedrukt worden. De
                            effectiviteit zal dus op een andere manier gemeten moeten worden, bijvoorbeeld door de
                            wachttijden in kaart te brengen en door enquêtes bij de cliënten te houden over de </span><a
                            class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                            href="javascript:" id="id-9e6d66ee-d7dd-486c-adc6-0a06df60bcfb" type="reference"
                            data-pixel="Link"><span><span class="">dienstverlening</span></span></a><span class="">.
                            Meting van de </span><a
                            class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                            href="javascript:" id="id-b590f59e-cde9-430f-f4c1-755c3345033e" type="reference"
                            data-pixel="Link"><span><span class="">efficiëntie</span></span></a><span class=""> kan ook
                            bij non-profitinstellingen plaatsvinden door een kostprijs te berekenen. Bij de stichting
                            voor slachtofferhulp kan bijvoorbeeld berekend worden wat de kostprijs is van een consult
                            van een uur.</span></p>
                </li>
            </ul>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-b75af379-ce13-4b19-e90d-a1579dd369fb" type="p"><span class="">De onderwerpen die in dit boek aan
                    de orde komen, zijn vooral van toepassing op ondernemingen. Voor een groot deel zijn ze ook relevant
                    voor non-profitinstellingen. Dit geldt met name voor de onderwerpen die in het deel </span><a
                    variant="body1" id="id-32671438-b197-4690-9061-dbf45ce4df58" class=" pl-reference" type="reference"
                    color="default" data-type="edify-cross-link" href="#cross-link"><span class="">Management
                        Accounting</span></a><span class=""> aan de orde zullen komen, omdat ook non-profitinstellingen
                    ernaar zullen streven om zo efficiënt mogelijk te werken.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-915dbf8c-02ad-4539-aff0-50a64706e29f" type="p"><span class="">In deel </span><a variant="body1"
                    id="id-cf3994f0-4afb-4638-9f94-00bfbaa51b96" class=" pl-reference" type="reference" color="default"
                    data-type="edify-cross-link" href="#cross-link"><span class="">Financiering</span></a><span
                    class=""> komt een aantal vermogensbronnen aan bod die alleen voor ondernemingen beschikbaar zijn,
                    zoals aandelenvermogen. De overige onderwerpen zijn ook van toepassing op
                    non-profitorganisaties.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-a3899153-a767-4981-93c5-1ba572225334" type="p"><span class="">De financiële rapportage zoals die
                    in deel </span><a variant="body1" id="id-406550c9-248f-4925-a47d-c836b00510e6" class=" pl-reference"
                    type="reference" color="default" data-type="edify-cross-link" href="#cross-link"><span
                        class="">Financial Accounting</span></a><span class=""> behandeld zal worden, kan ook toegepast
                    worden op non-profitorganisaties, waarbij het behalen van winst niet automatisch betekent dat de
                    organisatie goed heeft gefunctioneerd, omdat winst maken niet het primaire doel van de
                    non-profitsector is.</span></p>
            <div class=" pl-div  internet MuiBox-root css-1xdhyk6" id="id-575b7518-400b-416a-c392-712f8fdd2eb5"
                type="div">
                <div class="pl-div-children">
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  title pl-paragraph title css-9rabg7"
                        id="id-e40cadc4-e84b-4e69-c138-d2a3bc1c401f" type="p"><span class="">Baten en lasten World
                            Wildlife Fund in 2020</span></p>
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-546b1ee6-4a17-4bfb-ef23-0d86e31dd244" type="p"><span class="">Bron: </span><a
                            class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-link css-1xya16h"
                            id="id-fce504cd-014c-404f-b9fb-88f4cb864200" type="link" target="_blank"
                            rel="noopener noreferrer" href="http://www.panda.org" data-pixel="Link"><span><span
                                    class="">http://www.panda.org</span></span></a></p>
                    <figure id="id-66837e67-9b5a-413b-8162-3e2ce0bb4ea5" class="pl-figure-img  css-1hxcr1q">
                        <div class="pl-image-box MuiBox-root css-0"><img class="pl-image css-tw5ok2"
                                src="https://damapi-assets.edify.noordhoff.nl/image-output/edify-casper.prd-noordhoff.be70d024-7086-4835-bbc4-89c7b88d6895/fontopreview.jpeg?lastmodified=1639998311326"
                                alt="" loading="lazy"></div>
                    </figure>
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-5f317fde-c8a5-4549-c763-7d4b0650a382" type="p"><span class="">Total WWF Network donated
                            income increased by 16%, mainly driven by higher income from individuals (up 16%), public
                            sector (up 14%) and trusts &amp; foundations (up 16%), offset by a decrease in investment
                            income with a total income growth of 14%. Expenditure increased by 4%.</span></p>
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-aedd81cb-55a7-4abc-fe17-b73e8bf2b900" type="p"><span class="">The figures given show WWF
                            Network income and expenditure but do not represent consolidated accounts. The WWF Network
                            include WWF International, program offices and national organizations.</span></p>
                </div>
            </div>
        </div>
    </div>
    <div class="ChapterTheory_theoryContainer__1eB0z">
        <h2 class="ChapterTheory_slideTitle__1QHC_" data-cy="slide-title">4. Ondernemingsactiviteiten</h2>
        <div class="Edify_container__yGkKg" data-cy="">
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="5b12bf44-9895-4e3a-8955-95a96718a3fb" type="p"><b class="">Sectoren</b></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-19a4428f-45ab-417a-892d-41411b1d8701" type="p"><span class="">In paragraaf </span><a
                    variant="body1" id="id-8a0c3464-f28d-4f08-e771-a3736e33ba79" class=" pl-reference" type="reference"
                    color="default" data-type="edify-cross-link" href="#cross-link"><span class="">Kenmerken van
                        ondernemingen</span></a><span class=""> hebben we een </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-6aff8e58-d4f7-4edd-8682-d608cb1a17ba" type="reference"
                    data-pixel="Link"><span><span class="">Onderneming</span></span></a><span class=""> omschreven als
                    een op </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-b3cf72f2-da56-40db-c856-4de9a057c7d2" type="reference"
                    data-pixel="Link"><span><span class="">winst</span></span></a><span class=""> gerichte
                    productieorganisatie. De onderneming probeert winst te behalen door productiemiddelen in te kopen en
                    die te gebruiken door ze om te zetten in goederen of diensten die verkocht worden tegen een hogere
                    prijs dan de prijzen die betaald zijn op de inkoopmarkt.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-98c45f3c-c7ef-4af6-f63a-bca8dd969f50" type="p"><span class="">We kunnen een globale indeling van
                    bedrijven maken naar de aard van het omzettingsproces:</span></p>
            <ul class="  css-8ac2me" id="id-412e72a5-98fd-4f2b-f8e0-4cd1983adfee">
                <li id="id-52babc5c-3c7f-40d1-97ee-acfe92be8201" class="css-i27ntf">
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-d8f3a556-e521-4619-dafb-59ced7ba6333" type="p"><span class="">primaire sector: land- en
                            bosbouw, visserij en mijnbouw (</span><i class="">agriculture and forestry, fishing and
                            mining</i><span class="">)</span></p>
                </li>
                <li id="id-e9441dfd-379c-4130-9e1c-0303998907cb" class="css-i27ntf">
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-668f3b0c-0ed8-4443-cb1c-7b8a66083e8e" type="p"><span class="">secundaire sector:
                        </span><a
                            class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                            href="javascript:" id="id-885b4686-c235-4c3d-ac6c-4e0805368171" type="reference"
                            data-pixel="Link"><span><span class="">industrie</span></span></a><span class=""> (</span><i
                            class="">manufacturing</i><span class="">)</span></p>
                </li>
                <li id="id-e1856b07-0316-4ea6-b104-ad52dc6a719b" class="css-i27ntf">
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-029994f9-6636-484a-90f0-24667aeb016f" type="p"><span class="">tertiaire sector: </span><a
                            class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                            href="javascript:" id="id-0065f480-7fe1-43ac-b506-965bad0d7690" type="reference"
                            data-pixel="Link"><span><span class="">handel</span></span></a><span class=""> (</span><i
                            class="">trade</i><span class="">)</span></p>
                </li>
                <li id="id-227b524b-7261-4791-c2c7-770c938aafe7" class="css-i27ntf">
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-74edffde-1bcd-4932-b3a0-af90e9d717ba" type="p"><span class="">quartaire sector: </span><a
                            class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                            href="javascript:" id="id-9c19c22b-dbd4-4b85-8b6a-466af1f3cffa" type="reference"
                            data-pixel="Link"><span><span class="">dienstverlening</span></span></a><span class="">
                            (</span><i class="">services</i><span class="">)</span></p>
                </li>
            </ul>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-af37c973-c575-45c5-b6ae-6806e41abf42" type="p"><span class="">In de figuren </span><a
                    variant="body1" id="id-6ce924be-7358-4848-8110-26f1474eaa87" class=" pl-reference" type="reference"
                    color="default" href="#id-8645e65a-d9fc-4b38-e187-67ee357269d9"><span class="">Aantal bedrijven per
                        sector in de Europese Unie (2016)</span></a><span class=""> en </span><a variant="body1"
                    id="id-0a91d850-d7be-4f51-a863-40b202a7b7c6" class=" pl-reference" type="reference" color="default"
                    href="#id-c46fd026-e767-4107-f848-dd69c59ad208"><span class="">Aantal bedrijven per sector in
                        Nederland (2019)</span></a><span class=""> geven we een overzicht van het procentuele belang van
                    de vier sectoren in de Europese en de Nederlandse </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-5659f0ad-9a92-4833-ee5b-3404c179a065" type="reference"
                    data-pixel="Link"><span><span class="">economie</span></span></a><span class="">.</span></p>
            <figure id="id-8645e65a-d9fc-4b38-e187-67ee357269d9" class="pl-figure-img  css-1hxcr1q">
                <div class="pl-image-box MuiBox-root css-0"><img class="pl-image css-tw5ok2"
                        src="https://damapi-assets.edify.noordhoff.nl/image-output/edify-casper.prd-noordhoff.bcb95a67-02a1-49fc-a74b-ece23dec8288/fontopreview.jpeg?lastmodified=1604578595513"
                        alt="" loading="lazy"></div>
                <div class="pl-figure-description MuiBox-root css-dz0mqj">
                    <h4 class="MuiTypography-root MuiTypography-playerTitle MuiTypography-gutterBottom  pl-title css-1ny8nnn"
                        id="id-4da077bb-3da6-4852-c0ef-f8756792038c" type="title"><span class="">Aantal bedrijven per
                            sector in de Europese Unie (2016)</span></h4>
                    <div class="MuiBox-root css-y10vwx">
                        <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                            id="id-a417bb39-8e02-44c0-9e30-d95009dc3ea1" type="p"><span class="">Bron: Eurostat</span>
                        </p>
                    </div>
                </div>
            </figure>
            <figure id="id-c46fd026-e767-4107-f848-dd69c59ad208" class="pl-figure-img  css-1hxcr1q">
                <div class="pl-image-box MuiBox-root css-0"><img class="pl-image css-tw5ok2"
                        src="https://damapi-assets.edify.noordhoff.nl/image-output/edify-casper.prd-noordhoff.990502a0-e28b-445b-ba5a-baff5b8831d7/fontopreview.jpeg?lastmodified=1604578629081"
                        alt="" loading="lazy"></div>
                <div class="pl-figure-description MuiBox-root css-dz0mqj">
                    <h4 class="MuiTypography-root MuiTypography-playerTitle MuiTypography-gutterBottom  pl-title css-1ny8nnn"
                        id="id-b45bb1df-0cf9-4d9d-dea7-8912c186c707" type="title"><span class="">Aantal bedrijven per
                            sector in Nederland (2019)</span></h4>
                    <div class="MuiBox-root css-y10vwx">
                        <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                            id="id-3c02fff0-c6b6-437f-a461-12b7c3aeda0c" type="p"><span class="">Bron: CBS</span></p>
                    </div>
                </div>
            </figure>
            <div class=" pl-example  example MuiBox-root css-1xdhyk6" id="id-a7b67ff3-2e5e-4e32-de38-59f28e864f62"
                type="example">
                <div class="pl-example-children">
                    <figure id="id-45c9120c-6e03-4c40-ca70-57ca5a48a20c" class="pl-figure-img  css-1hxcr1q">
                        <div class="pl-image-box MuiBox-root css-0"><img class="pl-image css-tw5ok2"
                                src="https://damapi-assets.edify.noordhoff.nl/image-output/edify-casper.prd-noordhoff.c34e57c2-820b-4d02-8393-dfa1dcfdbb6c/fontopreview.jpeg?lastmodified=1604671144809"
                                alt="" loading="lazy"></div>
                    </figure>
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-b9f479b5-93db-4ff8-ea61-28868b092bb3" type="p"><span class="">Het opvallende verschil
                            tussen het aandeel van de primaire sector in Europa en in Nederland wordt verklaard door de
                            sterke automatisering en de </span><a
                            class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                            href="javascript:" id="id-6a15332b-9180-4ed2-8099-40bf4eefa494" type="reference"
                            data-pixel="Link"><span><span class="">overname</span></span></a><span class=""> van kleine
                            boerderijen in de agrarische sector in Nederland. Met name in de Oost-Europese landen vind
                            je nog veel kleine landbouwbedrijven. De gemiddelde grootte van een boerderij in Roemenië is
                            bijvoorbeeld 3,6 hectare, terwijl dit in Nederland 32,5 hectare is.</span></p>
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-20471b1e-806c-4297-fede-dab6b143cfc2" type="p"><span class="">De nu al grote betekenis
                            van de sector dienstverlening neemt nog steeds toe. Een onderzoek van
                            bedrijfsinformatiespecialist Graydon naar de groei van het aantal Nederlandse bedrijven in
                            het eerste kwartaal van 2019 laat zien dat de grootste groei zich voordoet in de zakelijke
                            dienstverlening.</span></p>
                    <figure id="id-09ca0cb3-2c81-4492-c672-e60a97c0cbb2" class="pl-figure-img  css-1hxcr1q">
                        <div class="pl-image-box MuiBox-root css-0"><img class="pl-image css-tw5ok2"
                                src="https://damapi-assets.edify.noordhoff.nl/image-output/edify-casper.prd-noordhoff.ec1f2afe-2d27-4cb9-982c-863ddbf562f2/fontopreview.jpeg?lastmodified=1604578695243"
                                alt="" loading="lazy"></div>
                    </figure>
                </div>
            </div>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-1dd7581f-9215-43bd-bc96-6334bf4c4673" type="p"></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="dd2cc2ce-9d88-4da2-878b-261d830df86e" type="p"><b class="">Land- en bosbouw, visserij en
                    mijnbouw</b></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-db8c4f70-6ef1-4e3e-bbe3-69f586f0649a" type="p"><span class="">Typerend voor ondernemingen in deze
                    categorie is dat ze gebruikmaken van de ‘rijkdommen van de natuur’. Met relatief weinig grondstof
                    wordt een grote hoeveelheid eindproduct verkregen. De </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-9e803d10-f2fb-46a3-af04-4047c19593dd" type="reference"
                    data-pixel="Link"><span><span class="">kosten</span></span></a><span class=""> van het zaaigoed van
                    een landbouwer maken slechts een zeer gering percentage uit van de opbrengst van de oogst. Bij
                    bedrijven die zich bezighouden met de winning van delfstoffen zoals bijvoorbeeld goud, koper, gas of
                    olie, wordt er zelfs helemaal geen gebruikgemaakt van grondstoffen.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-9b981b84-6590-47b4-b398-23c6c2da48ad" type="p"><span class="">Uiteraard zijn de duurzame
                    productiemiddelen wel zeer belangrijk: de landbouwgrond voor de agrariër, de boot voor de visser, de
                    vergunning voor de mijn of het olieveld; ook kan er een grote inzet van materieel zijn.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="c0386595-9133-4523-bb85-e8841bf85bf5" type="p"><b class="">Industrie</b></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-6d1b37f3-61a3-45c2-e349-ade39753df77" type="p"><span class="">Industriële ondernemingen creëren
                    een fysiek, tastbaar product dat voor de </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-16355101-c3e6-415e-a19c-b15991f3674b" type="reference"
                    data-pixel="Link"><span><span class="">productie</span></span></a><span class=""> in die vorm nog
                    niet bestond. De bouwbedrijven zijn onderdeel van deze sector.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-dc844734-a0e8-40d7-eea0-d1d5678456e8" type="p"><span class="">In het algemeen kan onderscheid
                    gemaakt worden tussen </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-cd48bdb8-e86e-4cb3-addc-12010c3d22f5" type="reference"
                    data-pixel="Link"><span><span class="">stukproductie</span></span></a><span class=""> en </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-0ea1359f-23bb-46d4-b40a-6ca885313d1e" type="reference"
                    data-pixel="Link"><span><span class="">massaproductie</span></span></a><span class="">. Bij
                </span><span id="marginWord-Stukproductie" class="css-0"></span><i class="">stukproductie</i><span
                    class=""> (</span><i class="">job production</i><span class="">) wordt ‘maatwerk’ geleverd. Elk
                    product is afgestemd op de specifieke wensen van de klant. Er is sprake van productie op bestelling:
                    eerst wordt de verkoop verricht en daarna begint de productie. Bij stukproductie doet zich dus geen
                    voorraadvorming van nog niet verkocht gereed product voor. Een werf die plezierjachten bouwt op
                    specificatie van de klant, is een voorbeeld van stukproductie.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-c12b625b-18c4-41b9-f37a-b79643cec114" type="p"><span class="">Bij </span><span
                    id="marginWord-Massaproductie" class="css-0"></span><i class="">massaproductie</i><span class="">
                    (</span><i class="">mass production</i><span class="">) wordt één soort product gemaakt in grote
                    hoeveelheden. Er wordt geen rekening gehouden met specifieke klantwensen. Meestal wordt op voorraad
                    geproduceerd. Een suikerfabriek is een voorbeeld van massaproductie.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-e3898302-1f9e-4e25-8966-83c2af3fc106" type="p"><span class="">In tabel </span><a variant="body1"
                    id="id-fc62366a-6baa-4879-f3b2-4c5229d3f82d" class=" pl-reference" type="reference" color="default"
                    href="#id-d71978b4-f440-4965-c387-c85714a1ea80"><span class="">Verschillen tussen stuk- en
                        massaproductie</span></a><span class=""> vatten we de verschillen tussen stuk- en massaproductie
                    samen.</span></p>
            <figure id="id-d71978b4-f440-4965-c387-c85714a1ea80" class="pl-figure-img  css-1hxcr1q">
                <div class="pl-image-box MuiBox-root css-0"><img class="pl-image css-tw5ok2"
                        src="https://damapi-assets.edify.noordhoff.nl/image-output/edify-casper.prd-noordhoff.90c56009-5716-4e46-b0d5-5615add69591/fontopreview.jpeg?lastmodified=1618586346905"
                        alt="" loading="lazy"></div>
                <div class="pl-figure-description MuiBox-root css-dz0mqj">
                    <h4 class="MuiTypography-root MuiTypography-playerTitle MuiTypography-gutterBottom  pl-title css-1ny8nnn"
                        id="id-5698f115-cf5c-41fe-bc15-dac91e354e38" type="title"><span class="">Verschillen tussen
                            stuk- en massaproductie</span></h4>
                </div>
            </figure>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-a56e0a82-be2f-4de1-be80-8a8e3f19aca8" type="p"><span class="">Tussen de twee uitersten (stuk- en
                    massaproductie) komen tussenvormen voor waarbij gebruik wordt gemaakt van de productie van series
                    identieke (half)producten (</span><i class="">batch production</i><span class="">).</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-a697701b-7c32-4466-cfeb-5dbb04699cea" type="p"><span class="">Bij </span><i
                    class="">serie-stukproductie</i><span class=""> houdt men vast aan de gedachte dat de klant zijn
                    eigen individueel bepaalde product krijgt, maar probeert men kosten te besparen door de componenten
                    van het product in grotere aantallen (en dus goedkoper) te produceren. Als de eerdergenoemde
                    jachtwerf diverse modellencasco’s, masten, kajuiten en dergelijke in series produceert en de klant
                    vervolgens een combinatie laat maken uit de beschikbare componenten om zijn eigen ‘droomboot’ samen
                    te stellen, is er sprake van serie-stukproductie.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-133994f4-8684-49f2-8b01-3d1a27506076" type="p"><span class="">Bij </span><i
                    class="">serie-massaproductie</i><span class=""> worden er varianten of modellen van het
                    standaardproduct geproduceerd, waarbij eens in de zoveel tijd de machines omgesteld dienen te worden
                    naar de betreffende variant. Als de suikerfabriek niet alleen suiker in korrelvorm produceert, maar
                    af en toe omschakelt naar suikerklontjes, doet zich serie-massaproductie voor.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-0bd2f701-8c56-45aa-9640-52cadcde118e" type="p"><span class="">Het belang van de drie ‘inputs’
                    (grondstof, duurzame productiemiddelen en menselijke arbeidskracht) voor een industriële onderneming
                    hangt af van het soort onderneming.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-9fddfb1c-39ef-4a4f-eddb-eab7a608aabb" type="p"><span class="">Bij een olieraffinaderij zullen de
                    grondstof en de duurzame productiemiddelen een zeer belangrijk deel van de kosten uitmaken, terwijl
                    bij een producent van ambachtelijke houten keukens de arbeidskosten overheersend zijn. Naarmate er
                    meer geautomatiseerd gaat worden, neemt het belang van de duurzame productiemiddelen in het geheel
                    van de kosten toe.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="47d67f1d-d2f3-45bd-938d-2173b07f8cd7" type="p"><b class="">Handel</b></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-2e689445-9841-488c-bb7f-62d921296704" type="p"><span class="">Handelsondernemingen produceren
                    geen nieuwe producten. Er is dus geen transformatieproces in technische zin. Handelsondernemingen
                    ontlenen hun bestaansrecht aan het feit dat er geen gelijkheid is tussen productie en consumptie.
                    Deze ongelijkheid kan betrekking hebben op:</span></p>
            <ol class="  css-lc01e8" id="id-45a49c03-8f59-4bf4-8832-594f0512a04e">
                <li id="id-4362efec-fea3-4b52-f776-793eab1a6ad4" class="css-i27ntf">
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-8e31d76f-1acc-4cc8-fc1f-1f535a83fafb" type="p"><span class="">de grootte van de productie
                            en consumptie</span></p>
                </li>
                <li id="id-51f00434-d178-4c06-a02f-f07ae971f9ed" class="css-i27ntf">
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-43c12dd0-c2b9-4514-cd64-64475137d122" type="p"><span class="">de samenstelling van de
                            productie en consumptie</span></p>
                </li>
                <li id="id-cdab748e-8885-4fa0-cf07-a370b16cfe84" class="css-i27ntf">
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-d8d52246-2a28-47b4-85b8-d30da008295d" type="p"><span class="">het tijdstip van de
                            productie en consumptie</span></p>
                </li>
                <li id="id-f884597c-3688-4a53-edbb-8d296b05817d" class="css-i27ntf">
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-a7765e2c-f0fe-4d87-eb44-d6579713a21b" type="p"><span class="">de plaats van de productie
                            en consumptie.</span></p>
                </li>
            </ol>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-548ef0a0-2e87-43a7-a3b5-480f1cbffc21" type="p"><span class="">In onderstaande </span><a
                    variant="body1" id="id-5ef65893-e7b4-486f-8d02-ad2550ea9afd" class=" pl-reference" type="reference"
                    color="default" href="#id-d84ffa6b-e226-455b-a5e2-52e97c482d53"><span
                        class="">voorbeeld</span></a><span class=""> beschrijven we een situatie waarin elk van deze
                    vier vormen van ongelijkheid voorkomt.</span></p>
            <div class=" pl-example  example MuiBox-root css-1xdhyk6" id="id-d84ffa6b-e226-455b-a5e2-52e97c482d53"
                type="example">
                <div class="pl-example-children">
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-387fd5c7-4528-4174-aabd-03be728b5fe8" type="p"><span class="">Het is voor een Japanse
                            fabrikant van computers problematisch om rechtstreeks een computer te slijten aan een
                            Nederlandse koper. Handelsondernemingen lossen dit probleem op. Een keten van computershops
                            kan vanuit Japan veel computers importeren (1), daarnaast andere artikelen in het
                            assortiment opnemen die de klant eveneens nodig heeft (2), een voorraad aanhouden zodat de
                            klant op elk gewenst moment zijn computer kan kopen (3) en in de buurt van de koper zijn
                            waren aanbieden (4).</span></p>
                </div>
            </div>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-9c30971f-1509-4701-b416-3243ccbfd160" type="p"><span class="">Het transformatieproces bij de
                    handel houdt dus een transformatie naar grootte, assortiment, tijd en plaats in. Bij
                    handelsondernemingen kan een onderscheid gemaakt worden tussen groothandel en detailhandel. De
                </span><span id="marginWord-Detailhandel" class="css-0"></span><i class="">detailhandel</i><span
                    class=""> (</span><i class="">retail trade</i><span class="">) is de ‘laatste schakel’; de
                    detailhandel levert rechtstreeks aan de eindgebruiker van de goederen: de consument. De </span><span
                    id="marginWord-Groothandel" class="css-0"></span><i class="">groothandel</i><span class="">
                    (</span><i class="">wholesale trade</i><span class="">) koopt in bij de fabrikant en verdeelt de
                    ingekochte partijen over de detailhandel. De groothandel wordt gekarakteriseerd door
                    ‘business-to-business’: zowel de leveranciers als de klanten zijn bedrijven. Om zijn zelfstandige
                    functie in het economisch leven waar te maken, zal de groothandel vooral sterk moeten zijn in het
                    zorgdragen dat de juiste producten op de juiste tijd in de winkel liggen. Dat vereist belangrijke
                    investeringen in logistieke systemen.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-9902eba1-13e6-4db0-8a1d-109023701a16" type="p"><span class="">De kosten van de handel bestaan
                    voor een belangrijk deel uit de ingekochte handelsgoederen. Daarnaast worden natuurlijk duurzame
                    productiemiddelen ingezet (bedrijfspanden, auto’s en dergelijke). Ook de kosten van menselijke
                    arbeid kunnen aanzienlijk zijn, vooral in de detailhandel.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-ee657382-a023-4f89-c887-151101b9bfcc" type="p"><span class="">Door de opkomst van internet vinden
                    grote veranderingen plaats in de handel. Met name de detailhandel staat onder druk. Via webwinkels
                    kan de groothandel of zelfs de fabrikant rechtstreeks producten verkopen aan de consument.</span>
            </p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="3d5a1ed1-7e3b-486d-bc56-52ff269f27b5" type="p"><b class="">Dienstverlening</b></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-8ce68b00-73f4-445a-f7bb-1c736a42c087" type="p"><span class="">Ondernemingen die zich bezighouden
                    met dienstverlening, verrichten prestaties voor hun klanten zonder dat zij een nieuw concreet
                    product vervaardigen of een bestaand product overdragen. Hieronder vallen bedrijven van zeer
                    uiteenlopende aard.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-9b8cad82-95e7-429d-e444-ff062e2e06fc" type="p"><span class="">We noemen enige belangrijke
                    categorieën:</span></p>
            <ul class="  css-8ac2me" id="id-4ae42965-aeba-4bae-b122-9fa75ae80d74">
                <li id="id-e5cd14ca-31f5-4d9b-beaf-abdf365786c2" class="css-i27ntf">
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-eeb52bb6-ce42-4e52-e0cf-fb3d477e9e43" type="p"><span class="">financiële dienstverlening
                            (banken, verzekeraars)</span></p>
                </li>
                <li id="id-3a4a2b0d-d1f0-4dac-a2fc-33ae879744d9" class="css-i27ntf">
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-28cbc2e4-ac1f-4f12-ac85-83ad1276c751" type="p"><span class="">horeca</span></p>
                </li>
                <li id="id-b209a439-9bd4-4905-96e7-00ed90747db8" class="css-i27ntf">
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-8b06437c-4265-458a-95b3-5fc0225f0dca" type="p"><span class="">transport</span></p>
                </li>
                <li id="id-eb9ab158-8bcf-4565-b462-aceaccc65b19" class="css-i27ntf">
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-62f2d205-3d27-435c-829d-5f204d017eaf" type="p"><span class="">ICT-dienstverlening
                            (softwarebureaus, computeradviesbureaus)</span></p>
                </li>
                <li id="id-42b9d6a6-712d-46c1-dbc6-71503262b274" class="css-i27ntf">
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-3065dda9-3697-4ff8-fc8a-a6868d4e87f7" type="p"><span class="">facilitaire dienstverlening
                            (bewaking, catering, schoonmaak).</span></p>
                </li>
            </ul>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-4e3a56af-b3d7-4f71-abb2-600729fc619c" type="p"><span class="">Kenmerkend voor de dienstverlening
                    is dat er geen (of nauwelijks) grondstoffen worden ingekocht bij leveranciers. De duurzame
                    productiemiddelen zijn in sommige dienstverlenende bedrijven zeer belangrijk: denk aan het hotel dat
                    gevestigd is in een pand in het centrum van een grote stad, of aan een rederij met een vloot
                    containerschepen. De arbeidskosten vormen bijna altijd een belangrijke kostenpost; de
                    dienstverlening is een ‘people business’: denk bijvoorbeeld aan de IT-specialisten die bij een
                    softwareleverancier werken of de bewakers bij een beveiligingsdienst.</span></p>
        </div>
    </div>
    <div class="ChapterTheory_theoryContainer__1eB0z">
        <h2 class="ChapterTheory_slideTitle__1QHC_" data-cy="slide-title">5. Bedrijfskolom en bedrijfstak</h2>
        <div class="Edify_container__yGkKg" data-cy="">
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-7772a584-2586-47ab-b325-a095b3912846" type="p"><span class="">Een </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-72fb7ced-5211-4cd2-cfa1-5b0dcaa73ecb" type="reference"
                    data-pixel="Link"><span><span class="">bedrijf</span></span></a><span class=""> verzorgt vrijwel
                    nooit zelfstandig het gehele traject van winning van grondstoffen tot het verkopen van een gereed
                    product aan de klant. Er is vrijwel altijd sprake van een opeenvolging van bedrijven die elkaar
                    grondstoffen of halffabricaten leveren en die ieder een volgende bewerkingsslag maken in de
                    totstandkoming van het eindproduct. We spreken dan van een </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-9e7fd66c-ed5b-4ed7-a22b-3cd970d30675" type="reference"
                    data-pixel="Link"><span><span class="">bedrijfskolom</span></span></a><span class="">.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-e9095fe6-0d87-4692-8d68-10ba63553e42" type="p"><span class="">Een </span><i
                    class="">bedrijfskolom</i><span class=""> (</span><i class="">supply chain</i><span class="">) vormt
                    de totale keten van bedrijven die betrokken zijn bij de voortbrenging van een product of dienst, het
                    geheel van stadia dat een product doorloopt op zijn weg van producent naar consument.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-97525b84-7cff-44a4-c8b0-8489fba8d7c1" type="p"><span class="">We laten in figuur </span><a
                    variant="body1" id="id-1d9b5299-a33f-497c-887b-29f3f010cad2" class=" pl-reference" type="reference"
                    color="default" href="#id-5026586d-c79c-4d86-eb76-9cd05dbae56e"><span
                        class="">Bedrijfskolommen</span></a><span class=""> twee bedrijfskolommen zien.</span></p>
            <figure id="id-5026586d-c79c-4d86-eb76-9cd05dbae56e" class="pl-figure-img  css-1hxcr1q">
                <div class="pl-image-box MuiBox-root css-0"><img class="pl-image css-tw5ok2"
                        src="https://damapi-assets.edify.noordhoff.nl/image-output/edify-casper.prd-noordhoff.c9df58c6-ede4-4ca4-9575-d24a1aa38b71/fontopreview.jpeg?lastmodified=1598372643244"
                        alt="" loading="lazy"></div>
                <div class="pl-figure-description MuiBox-root css-dz0mqj">
                    <h4 class="MuiTypography-root MuiTypography-playerTitle MuiTypography-gutterBottom  pl-title css-1ny8nnn"
                        id="id-e4b99393-f933-46e6-a1f8-608644d4db9f" type="title"><span class="">Bedrijfskolommen</span>
                    </h4>
                </div>
            </figure>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-7f3b5304-5907-49dc-ac5d-509b87634643" type="p"><span class="">De gezamenlijke bedrijven in een
                    schakel van een bedrijfskolom vormen een </span><i class="">bedrijfstak</i><span class="">
                    (</span><i class="">industry</i><span class="">). Zo vormen bijvoorbeeld alle supermarkten een
                </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-b972dcff-306b-4875-8dcd-045d32e9ffac" type="reference"
                    data-pixel="Link"><span><span class="">bedrijfstak</span></span></a><span class="">.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-00a27207-2d36-44d7-ffb6-026bbc149249" type="p"><span class="">Het komt wel degelijk voor dat een
                    bedrijf verschillende opeenvolgende schakels in een bedrijfskolom voor zijn rekening neemt.
                    Koninklijke Shell bijvoorbeeld wint de ruwe olie, verwerkt die in raffinaderijen tot verkoopbare
                    producten zoals diesel en benzine en verkoopt deze aan de pomp. In zo’n geval spreken we van
                </span><span id="marginWord-Integratie" class="css-0"></span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-d2ddbfc5-a677-4ae4-99e1-43f942f17f0f" type="reference"
                    data-pixel="Link"><span><i class="">integratie</i></span></a><span class=""> (</span><i
                    class="">vertical integration</i><span class="">).</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-83c77487-8232-4a23-ea48-a47283bd1872" type="p"><span class="">Overigens is niet elk Shell
                    tankstation eigendom van Koninklijke Shell. Er is dan sprake van een zelfstandig ondernemer die zijn
                    producten afneemt van Shell. In de volgende paragraaf komen we op zo’n samenwerkingsvorm
                    terug.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-2457a485-a6c5-46bc-febb-fddf8bc1df3d" type="p"><span class="">Ook komt het vaak voor dat
                    bedrijven actief zijn in een vergelijkbare schakel in verschillende bedrijfskolommen. Een voorbeeld
                    is een tankstation dat niet alleen diesel en benzine verkoopt maar in de shop ook consumptiegoederen
                    als frisdrank, ijs, snoepgoed, broodjes en zelfs een volledig levensmiddelenaanbod heeft. Een
                    dergelijke verbreding van het assortiment is een vorm van </span><span
                    id="marginWord-Parallellisatie" class="css-0"></span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-42d0b693-64cf-4aea-a918-196f69354602" type="reference"
                    data-pixel="Link"><span><i class="">parallellisatie</i></span></a><span class=""> (</span><i
                    class="">horizontal integration</i><span class="">).</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-5effab6d-960c-4cb6-915b-20827659db12" type="p"><span class="">Sommige bedrijven zijn zo groot
                    geworden dat ze opereren in verschillende schakels van verschillende bedrijfskolommen. In het
                    verleden zijn zo veel grote concerns ontstaan die actief waren in allerlei schakels van
                    verschillende bedrijfskolommen.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-b9cf8bda-c243-47ea-800b-04ac5de02f98" type="p"><span class="">Het argument hiervoor was dat er op
                    die manier een goede risicospreiding bereikt werd. Tegenwoordig zijn deze </span><span
                    id="marginWord-Conglomeraten" class="css-0"></span><i class="">conglomeraten</i><span class="">
                    (</span><i class="">conglomerates</i><span class="">) niet populair meer, omdat gebleken is dat het
                    voor de centrale leiding heel moeilijk is om een mix van verschillende bedrijfsonderdelen te
                    besturen. Daarom is de laatste jaren een trend waar te nemen die gekarakteriseerd kan worden als
                    ‘back to the core business’: </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-a2cf7b37-9abc-4c9d-bbeb-adab3aa6956a" type="reference"
                    data-pixel="Link"><span><span class="">ondernemingen</span></span></a><span class=""> gaan zich
                    concentreren op hun kernactiviteiten en verkopen bedrijfsonderdelen die daar niet in passen.</span>
            </p>
        </div>
    </div>
    <div class="ChapterTheory_theoryContainer__1eB0z">
        <h2 class="ChapterTheory_slideTitle__1QHC_" data-cy="slide-title">6. Samenwerkingsvormen tussen ondernemingen
        </h2>
        <div class="Edify_container__yGkKg" data-cy="">
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-cf017b73-2c38-4649-866e-0dd04e122d0b" type="p"><span class="">In de voorgaande paragraaf hebben
                    we gesproken over bedrijven die actief zijn in verschillende schakels van één of meerdere </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-d3974f9c-162b-4b40-e0bf-c2d2c6d65896" type="reference"
                    data-pixel="Link"><span><span class="">bedrijfskolommen</span></span></a><span class="">.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-b68c027d-edfd-4d5d-a6fe-be5233fafffb" type="p"><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-34b25c6e-2082-466f-c6b0-9fdfcf6dde4b" type="reference"
                    data-pixel="Link"><span><span class="">Ondernemingen</span></span></a><span class=""> kunnen ook in
                    meer of mindere mate gaan samenwerken met andere ondernemingen. Zij geven daarmee hun
                    zelfstandigheid geheel of gedeeltelijk op. Wat eerst een concurrent was, wordt nu een collega. We
                    zullen vier vormen van samenwerking bespreken: </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-aaf3107e-576a-439b-ab24-0319b96f6bce" type="reference"
                    data-pixel="Link"><span><span class="">fusie</span></span></a><span class=""> en </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-5a24e4dc-27f0-4e52-bdd1-e0d986003434" type="reference"
                    data-pixel="Link"><span><span class="">overname</span></span></a><span class="">, </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-563089d3-8c23-4c65-a2a3-095dfeaa2174" type="reference"
                    data-pixel="Link"><span><span class="">joint venture</span></span></a><span class="">, </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-2b076d07-ba8b-4c06-f039-fac147c21bc7" type="reference"
                    data-pixel="Link"><span><span class="">franchising</span></span></a><span class=""> en
                    kartelvorming.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="3b1722b7-b1e7-4f9d-aa66-2ec499404999" type="p"><b class="">Fusie en overname</b></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-912f7981-6fde-4c76-e734-5137d60c174f" type="p"><span class="">Als een onderneming wil groeien,
                    kan zij zelf nieuwe activiteiten gaan opstarten. Het is vaak echter gemakkelijker om groei niet op
                    eigen kracht te bereiken, maar door een ander </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-74151dd9-ed5e-4ed4-c9d8-ed3a5452714c" type="reference"
                    data-pixel="Link"><span><span class="">bedrijf</span></span></a><span class=""> over te nemen. Een
                </span><span id="marginWord-Overname" class="css-0"></span><i class="">overname</i><span class="">
                    (</span><i class="">takeover</i><span class="">) wordt normaliter gerealiseerd doordat een
                    onderneming de aandelen van een ander bedrijf opkoopt. De term </span><span id="marginWord-Fusie"
                    class="css-0"></span><i class="">fusie</i><span class=""> (</span><i class="">merger</i><span
                    class="">) wordt gebruikt in de situatie dat er geen sprake is van een overnemer en een
                    overgenomene, maar van twee gelijkwaardige partijen die samensmelten.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-c153bf21-794b-43fc-f812-f8cab6278d9b" type="p"><span class="">Hoewel een overname een snelle
                    manier is om te groeien, worden de verwachte positieve effecten vaak overschat. Naar schatting
                    mislukt 65% tot 85% van de overnames in de zin dat er weinig toegevoegde waarde is van de
                    samengevoegde onderneming ten opzichte van de oorspronkelijke aparte ondernemingen. Oorzaken
                    hiervoor zijn bijvoorbeeld cultuurverschillen tussen de ondernemingen of het onvoldoende realiseren
                    van kostenbesparingen door grotere </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-8fd9efc5-79fa-4da7-9a22-fa6b63a1845b" type="reference"
                    data-pixel="Link"><span><span class="">efficiëntie</span></span></a><span class="">.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="1890b51c-38e6-43a2-9989-eaaf0f879d08" type="p"><b class="">Joint venture</b></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-ffd36fef-d82a-4190-995a-9b71297e581d" type="p"><span class="">Een </span><span
                    id="marginWord-Joint venture" class="css-0"></span><span class="">joint venture is een
                    samenwerkingsverband tussen twee bedrijven, waarbij zij samen een nieuw bedrijf opzetten. De
                    participerende bedrijven zijn samen eigenaar van de joint venture en delen zowel de </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-3af3b83b-7e9e-4b44-a045-0e4bc1865031" type="reference"
                    data-pixel="Link"><span><span class="">winst</span></span></a><span class=""> als eventuele
                    verliezen. De deelnemende bedrijven blijven zelfstandig bestaan.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-c41dd2f5-b0c5-4e5c-fc04-61381b14e55c" type="p"><span class="">De samenwerking kan betrekking
                    hebben op een veelheid aan activiteiten. De ondernemingen kunnen bijvoorbeeld samen research &amp;
                    development gaan doen, de </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-5e0af413-99ee-4627-e7c6-4963db82f256" type="reference"
                    data-pixel="Link"><span><span class="">productie</span></span></a><span class=""> gaan verzorgen,
                    een nieuw product lanceren of een nieuwe markt betreden.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-69fccf80-e076-4bbe-9c96-1fefa748303c" type="p"><span class="">Voordelen van samenwerking in een
                    joint venture in plaats van apart te opereren kunnen zijn:</span></p>
            <ul class="  css-8ac2me" id="id-d1bcb66c-b98e-4bbd-80c4-002ad9540069">
                <li id="id-ac9f095c-2da8-462b-eb41-2e57f5d22378" class="css-i27ntf">
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-d5b6a91e-92b6-4d88-ef4d-4ab6c06e62f6" type="p"><span class="">Het snel realiseren van
                            schaalvergroting met de bijkomende efficiencyvoordelen</span></p>
                </li>
                <li id="id-55b526e5-af02-4ccc-e421-ee5b661d025c" class="css-i27ntf">
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-63486af2-ee93-40b2-9ac8-a618e81556aa" type="p"><span class="">Gebruik maken van elkaars
                            kennis en technologie</span></p>
                </li>
                <li id="id-94e87e9c-6d3b-4532-80b7-b54910a25be1" class="css-i27ntf">
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-1e6972ec-8ec2-4738-fe28-2b1451a998fb" type="p"><span class="">Gebruik maken van elkaars
                            verkoop- en distributiesystemen</span></p>
                </li>
                <li id="id-00786cf3-86ca-4e0e-b874-2f2a6a444f78" class="css-i27ntf">
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-d6815d4e-d2ee-418f-c23d-567482d1607d" type="p"><span class="">Openbreken van buitenlandse
                            markt bij samenwerking met een buitenlandse partner als een regering van een land directe
                            import verbiedt of erg hoge invoerrechten heft.</span></p>
                </li>
            </ul>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-62e5542c-91a9-4b73-e40d-4992e0cc50e8" type="p"><span class="">Bekende joint ventures in de
                    koffiebranche zijn Senseo, Dolce Gusto en Nespresso, en in de mediawereld VodafoneZiggo.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="077a5cca-4466-4c3f-adab-38551b8b2661" type="p"><b class="">Franchising</b></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-8e518112-c232-41f5-ab54-af5b72030e85" type="p"><span class="">Een zeer veel voorkomende vorm van
                    samenwerking in zowel de productie- als de dienstensector is franchising. De Nederlandse Franchise
                    Vereniging (NFV) omschrijft franchising als volgt:</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-ebf4af00-c542-4a77-daab-ac54b4d4faf5" type="p"><span id="marginWord-Franchising"
                    class="css-0"></span><span class="">Franchising is een hechte vorm van samenwerking tussen juridisch
                    zelfstandige ondernemers, de franchisegever en de franchisenemer, die onder gebruikmaking van een
                    gemeenschappelijke naam en met een uniforme uitstraling producten en diensten aanbieden aan
                    afnemers.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-e7c80086-cfa3-496a-a1da-b6af6f1de911" type="p"><span class="">Bij franchising sluit een
                    zelfstandige ondernemer zich aan bij een keten en maakt daardoor gebruik van bepaalde faciliteiten,
                    zoals inkoop, marketing en winkelinrichting.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-b7508f45-a34e-4be9-9be4-54920e6a1459" type="p"><span class="">Voor de franchisegever is het
                    vooral van belang dat de zelfstandige ondernemer de plaatselijke markt veel beter kent. De
                    franchisenemer runt zijn bedrijf als zelfstandig ondernemer, maar treedt naar buiten toe op als
                    filiaalhouder van een grotere keten. De franchisegever begeleidt en controleert de zelfstandige
                    ondernemer. De franchisenemer betaalt een vergoeding (franchise-fee) aan de keten.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-8e89679a-967b-4673-89a2-8c5160c9827f" type="p"><span class="">Franchising komt tegenwoordig zeer
                    veel voor, zowel in de detailhandel als in de </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-950731ad-e627-463e-b62a-f6eb87aa7242" type="reference"
                    data-pixel="Link"><span><span class="">dienstverlening</span></span></a><span class="">. Bekende
                    voorbeelden van het franchiseconcept zijn Sport 2000, McDonalds en De Hypotheker.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="c1ef5185-bf17-4657-897d-371bf7a6e6f1" type="p"><b class="">Kartelvorming</b></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-d96eb66d-a4a5-4204-e885-d148d5480546" type="p"><span class="">Bij kartelvorming (</span><i
                    class="">cartelization</i><span class="">) maken zelfstandige producenten afspraken, die de vrije
                    concurrentie beperken. De mogelijkheid om dit soort afspraken te maken, is afhankelijk van de
                    marktvorm waarin de ondernemingen opereren.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-834d1cb2-5096-4b8c-c766-e9d8da3901c2" type="p"><span class="">Bij de marktvorm </span><span
                    id="marginWord-Volledige mededinging" class="css-0"></span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-c16ad6a9-2a1c-403d-8ada-aa9b0e3d5ce2" type="reference"
                    data-pixel="Link"><span><i class="">volledige mededinging</i></span></a><span class=""> (</span><i
                    class="">perfect competition</i><span class="">) zijn er veel ondernemingen en veel klanten in de
                </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-2b522dde-09ea-46bd-d537-375529976453" type="reference"
                    data-pixel="Link"><span><span class="">bedrijfstak</span></span></a><span class=""> en is er sprake
                    van een gestandaardiseerd product. Dit zal leiden tot zeer scherpe concurrentie. Het andere uiterste
                    is het </span><span id="marginWord-Monopolie" class="css-0"></span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-9b2092a1-baa0-49bf-e6d7-7e2b3c3bf3d9" type="reference"
                    data-pixel="Link"><span><i class="">monopolie</i></span></a><span class=""> (</span><i
                    class="">monopoly</i><span class="">): er is slechts één aanbieder, die dus geen concurrentie heeft
                    te vrezen. Kartelafspraken komen hier dus niet voor.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-83e88f57-779e-4bd6-be9e-9c78dfd9a72a" type="p"><span class="">Bij </span><span
                    id="marginWord-Oligopolie" class="css-0"></span><i class="">oligopolie</i><span class=""> (</span><i
                    class="">oligopoly</i><span class="">) is sprake van een relatief gering aantal aanbieders.</span>
            </p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-7a771928-4316-4c7e-956d-dbc5a30cf15d" type="p"><span class="">De wegenbouw is hiervan een
                    voorbeeld.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-1d499b95-7da8-47c6-bc85-14dd5ad3c6de" type="p"><span class="">Bij een </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-068d17a8-44d1-4217-e40d-976ff6c84925" type="reference"
                    data-pixel="Link"><span><span class="">oligopolie</span></span></a><span class=""> kunnen de
                    ondernemingen al vrij snel in de verleiding komen om afspraken met elkaar te maken over de te
                    hanteren verkoopprijzen. Ze kunnen er zelfs toe overgaan om de markt onder elkaar ‘te verdelen’. In
                    zo’n situatie is er sprake van een </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-0b32384b-bf01-4ff1-db90-50e9920a548c" type="reference"
                    data-pixel="Link"><span><span class="">kartel</span></span></a><span class="">. Vanwege de mogelijke
                    benadeling van consumenten staat de bestrijding van kartels hoog op de prioriteitenlijst van de
                    Europese Unie. Kartels zijn volgens de EU-concurrentieregels verboden en de Europese Commissie legt
                    bedrijven die deelnemen aan een kartel zware boetes op. Omdat kartels verboden zijn, worden
                    kartelafspraken meestal in het grootste geheim gemaakt, zodat het niet gemakkelijk is bewijzen van
                    het bestaan ervan te vinden. Met de ‘clementieregeling’ worden bedrijven aangemoedigd de Europese
                    Commissie inside-informatie over het bestaan van kartels te verstrekken. De karteldeelnemer die dit
                    als eerste doet, hoeft geen boete te betalen. Op de Nederlandse markt is bij de bestrijding van
                    kartelvorming een belangrijke rol weggelegd voor de Autoriteit Consument &amp; Markt (ACM), die
                    boetes kan opleggen aan bedrijven die onderlinge (prijs)afspraken maken.</span></p>
            <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                id="id-97bdd2c5-1b44-4812-9428-5e16f25a8d0b" type="p"><span class="">De problematiek van de marktvormen
                    met de daarbij behorende concurrentieverhoudingen behoort tot het terrein van de algemene </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-66a4d873-fb50-4d1a-82cb-24647a702bcb" type="reference"
                    data-pixel="Link"><span><span class="">economie</span></span></a><span class="">, maar heeft
                    uiteraard belangrijke consequenties voor de </span><a
                    class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom MuiLink-root MuiLink-underlineAlways  pl-reference css-1xya16h"
                    href="javascript:" id="id-3af8a86c-2f7d-440c-b12e-132ebec7564c" type="reference"
                    data-pixel="Link"><span><span class="">bedrijfseconomie</span></span></a><span class="">.</span></p>
            <div class=" pl-example  example MuiBox-root css-1xdhyk6" id="id-4f8e45d4-ccff-4f0d-8186-0754245d333f"
                type="example">
                <div class="pl-example-children">
                    <p class="MuiTypography-root MuiTypography-body1 MuiTypography-gutterBottom  pl-paragraph css-9rabg7"
                        id="id-ba35cd1f-d515-4f8e-d3ab-cdc9b6fe5b25" type="p"><span class="">In 2019 werd bekend dat de
                            Europese Commissie onderzoek doet naar illegale afspraken door Duitse autofabrikanten. Als
                            het wordt bewezen, is het autokartel een van de grootste kartelzaken in de Duitse
                            geschiedenis. Vijf Duitse automerken – BMW, Daimler en VW met Volkswagen, Porsche en Audi –
                            zouden decennialang afspraken hebben gemaakt om de invoering van schone technologie te
                            vertragen. De Europese Commissie onderzoekt verboden afspraken rond de invoer van
                            fijnstoffilters bij benzineauto’s en rond het formaat van tanks met de vloeistof die helpt
                            uitlaatgassen van dieselauto’s schoon te maken. Daimler stelt dat het geen boete krijgt,
                            omdat het bedrijf het kartel heeft verklikt aan de autoriteiten. Volkswagen zegt dat het
                            korting wil, omdat het meewerkt met de autoriteiten. De fabrikanten kunnen wel claims van
                            klanten krijgen.</span></p>
                </div>
            </div>
        </div>
    </div>
</div>"""

# %%
from typing_extensions import Text
from bs4 import BeautifulSoup
import re
html_content = html

soup = BeautifulSoup(html_content, 'html.parser')

output_text = ""
# Haal alle divjes met .pl-example class eruit, (blokjes met gele achtergrond)
for elem in soup.select(".pl-example"):
    elem.extract()

# Dit is vooral om de verschllende HTML elementen om te zetten naar Markdown achtige output.
for element in soup.find_all(['p', 'ul', 'li', 'h2', 'h4', 'b']):
    if element.name == 'p':
        output_text += element.get_text() + "``"
    elif element.name == 'ul':
        continue
    elif element.name == 'li':
        output_text += "- " + element.get_text() + ""
    elif element.name == 'b':
        output_text += "*" + element.get_text() + "* "
    elif element.name == 'h2':
        output_text += "## " + element.get_text() + "\n\n"
    elif element.name == 'h4':
        output_text += "#### " + element.get_text() + "\n\n"

text =  re.sub(r'\s+', ' ', output_text).strip()
text = text.replace('``', '\n\n')

text
# Out:
# "## 1. Economie en bedrijfseconomie Leerdoelen:\n\nHet verkrijgen van inzicht in:\n\n- de deelgebieden van economie (Economie en bedrijfseconomie) de deelgebieden van economie (Economie en bedrijfseconomie)\n\n- het studieobject van bedrijfseconomie (Economie en bedrijfseconomie) het studieobject van bedrijfseconomie (Economie en bedrijfseconomie)\n\n- de kenmerken van ondernemingen (Kenmerken van ondernemingen) de kenmerken van ondernemingen (Kenmerken van ondernemingen)\n\n- de betekenis van efficiëntie en effectiviteit voor het streven naar winst van een onderneming (Kenmerken van ondernemingen) de betekenis van efficiëntie en effectiviteit voor het streven naar winst van een onderneming (Kenmerken van ondernemingen)\n\n- de kenmerken van non-profitorganisaties (Kenmerken van non-profitorganisaties) de kenmerken van non-profitorganisaties (Kenmerken van non-profitorganisaties) \n\n- de indeling van bedrijven naar de vier hoofdsectoren (Ondernemingsactiviteiten) de indeling van bed
# ...

# %%
# Splitting de tekst on '##'
sections = text.split('##')

# En plakken de tekst achter ## er weer aan vast- en plaatsen hem terug.
sections = ['##' + section if index != 0 else section for index, section in enumerate(sections) if section.strip() != '']
sections
# Out:
# ['## 1. Economie en bedrijfseconomie Leerdoelen:\n\nHet verkrijgen van inzicht in:\n\n- de deelgebieden van economie (Economie en bedrijfseconomie) de deelgebieden van economie (Economie en bedrijfseconomie)\n\n- het studieobject van bedrijfseconomie (Economie en bedrijfseconomie) het studieobject van bedrijfseconomie (Economie en bedrijfseconomie)\n\n- de kenmerken van ondernemingen (Kenmerken van ondernemingen) de kenmerken van ondernemingen (Kenmerken van ondernemingen)\n\n- de betekenis van efficiëntie en effectiviteit voor het streven naar winst van een onderneming (Kenmerken van ondernemingen) de betekenis van efficiëntie en effectiviteit voor het streven naar winst van een onderneming (Kenmerken van ondernemingen)\n\n- de kenmerken van non-profitorganisaties (Kenmerken van non-profitorganisaties) de kenmerken van non-profitorganisaties (Kenmerken van non-profitorganisaties) \n\n- de indeling van bedrijven naar de vier hoofdsectoren (Ondernemingsactiviteiten) de indeling van be
# ...

# %%
# Hier komt dan de OPENAI Stuff die itereerd over het bovenstaande,
# Maar voor nu output hij naar het scherm met een section prefixed met een aantal +'jes
# (Dat gaat natuurlijk zo netjes weggewerkt worden)
for section in sections:
    # hele korte regels negeren, dit is vaak ruis.
    if len(section) > 10:
        print("++++++", section)
        print('-'*20)
# Out:
# ++++++ ## 1. Economie en bedrijfseconomie Leerdoelen:
#
# Het verkrijgen van inzicht in:
#
# - de deelgebieden van economie (Economie en bedrijfseconomie) de deelgebieden van economie (Economie en bedrijfseconomie)
#
# - het studieobject van bedrijfseconomie (Economie en bedrijfseconomie) het studieobject van bedrijfseconomie (Economie en bedrijfseconomie)
#
# - de kenmerken van ondernemingen (Kenmerken van ondernemingen) de kenmerken van ondernemingen (Kenmerken van ondernemingen)
#
# - de betekenis van efficiëntie en effectiviteit voor het streven naar winst van een onderneming (Kenmerken van ondernemingen) de betekenis van efficiëntie en effectiviteit voor het streven naar winst van een onderneming (Kenmerken van ondernemingen)
#
# - de kenmerken van non-profitorganisaties (Kenmerken van non-profitorganisaties) de kenmerken van non-profitorganisaties (Kenmerken van non-profitorganisaties)
#
# ...
